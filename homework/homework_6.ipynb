# %%
# %%
# =============================================================================
#
# Pronositco usando un stacked MLP
#
# =============================================================================
import warnings

warnings.filterwarnings("ignore")

#
# Carga de datos
#
import nbimporter  #  type: ignore
import functions  #  type: ignore


df_orig = functions.load_data()
df_orig.head()
# Out:
#             yt_true
# date
# 1946-01-01      890
# 1946-02-01      992
# 1946-03-01      979
# 1946-04-01      959
# 1946-05-01     1110

# %%
# %%

#
# Construcción de la matriz de regresores
#
df_orig = functions.make_lagged_ts(
    df=df_orig,
    p_max=13,
    y_column="yt_true",
    fmt="lagged_{}m",
)
df_orig.head()
# Out:
#             yt_true  lagged_1m  lagged_2m  lagged_3m  lagged_4m  lagged_5m  \
# date
# 1946-01-01      890        NaN        NaN        NaN        NaN        NaN
# 1946-02-01      992      890.0        NaN        NaN        NaN        NaN
# 1946-03-01      979      992.0      890.0        NaN        NaN        NaN
# 1946-04-01      959      979.0      992.0      890.0        NaN        NaN
# 1946-05-01     1110      959.0      979.0      992.0      890.0        NaN
#
#             lagged_6m  lagged_7m  lagged_8m  lagged_9m  lagged_10m  \
# date
# 1946-01-01        NaN        NaN        NaN        NaN         NaN
# 1946-02-01        NaN        NaN        NaN        NaN         NaN
# 1946-03-01        NaN        NaN        NaN        NaN         NaN
# 1946-04-01        NaN        NaN        NaN        NaN         NaN
# 1946-05-01        NaN        NaN        NaN        NaN         NaN
#
#             lagged_11m  lagged_12m  lagged_13m
# date
# 1946-01-01         NaN         NaN         NaN
# 1946-02-01         NaN         NaN         NaN
# 1946-03-01         NaN         NaN         NaN
# 1946-04-01         NaN         NaN         NaN
# 1946-05-01         NaN         NaN         NaN

# %%
# %%
#
# Remoción de los valores faltantes
#
df_dropna = df_orig.dropna()
df_dropna.head()
# Out:
#             yt_true  lagged_1m  lagged_2m  lagged_3m  lagged_4m  lagged_5m  \
# date
# 1947-02-01     1517     1488.0     1287.0     1301.0     1436.0     2092.0
# 1947-03-01     1707     1517.0     1488.0     1287.0     1301.0     1436.0
# 1947-04-01     1729     1707.0     1517.0     1488.0     1287.0     1301.0
# 1947-05-01     1788     1729.0     1707.0     1517.0     1488.0     1287.0
# 1947-06-01     2008     1788.0     1729.0     1707.0     1517.0     1488.0
#
#             lagged_6m  lagged_7m  lagged_8m  lagged_9m  lagged_10m  \
# date
# 1947-02-01     3401.0     1539.0     1546.0     1110.0       959.0
# 1947-03-01     2092.0     3401.0     1539.0     1546.0      1110.0
# 1947-04-01     1436.0     2092.0     3401.0     1539.0      1546.0
# 1947-05-01     1301.0     1436.0     2092.0     3401.0      1539.0
# 1947-06-01     1287.0     1301.0     1436.0     2092.0      3401.0
#
#             lagged_11m  lagged_12m  lagged_13m
# date
# 1947-02-01       979.0       992.0       890.0
# 1947-03-01       959.0       979.0       992.0
# 1947-04-01      1110.0       959.0       979.0
# 1947-05-01      1546.0      1110.0       959.0
# 1947-06-01      1539.0      1546.0      1110.0

# %%
# %%
#
# División de los datos en entrenamiento y prueba
#
(
    X_complete,
    y_complete,
    X_train,
    y_train,
    X_test,
    y_test,
) = functions.train_test_split(
    df=df_dropna,
    x_columns=[f"lagged_{i}m" for i in range(1, 13)],
    y_column="yt_true",
)
X_complete.head()
# Out:
#             lagged_1m  lagged_2m  lagged_3m  lagged_4m  lagged_5m  lagged_6m  \
# date
# 1947-02-01     1488.0     1287.0     1301.0     1436.0     2092.0     3401.0
# 1947-03-01     1517.0     1488.0     1287.0     1301.0     1436.0     2092.0
# 1947-04-01     1707.0     1517.0     1488.0     1287.0     1301.0     1436.0
# 1947-05-01     1729.0     1707.0     1517.0     1488.0     1287.0     1301.0
# 1947-06-01     1788.0     1729.0     1707.0     1517.0     1488.0     1287.0
#
#             lagged_7m  lagged_8m  lagged_9m  lagged_10m  lagged_11m  \
# date
# 1947-02-01     1539.0     1546.0     1110.0       959.0       979.0
# 1947-03-01     3401.0     1539.0     1546.0      1110.0       959.0
# 1947-04-01     2092.0     3401.0     1539.0      1546.0      1110.0
# 1947-05-01     1436.0     2092.0     3401.0      1539.0      1546.0
# 1947-06-01     1301.0     1436.0     2092.0      3401.0      1539.0
#
#             lagged_12m
# date
# 1947-02-01       992.0
# 1947-03-01       979.0
# 1947-04-01       959.0
# 1947-05-01      1110.0
# 1947-06-01      1546.0
